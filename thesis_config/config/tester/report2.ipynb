# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("/home/steven/thesis/mod")
from model_independent import model_independent
from model_independent import Growth_Factor
from model_independent import Report

a = np.loadtxt("a_bg.txt")
h0=0.6898
om=0.29044350092105475
report = Report(om=om,h0=h0,n=0)

# %%
c = np.array([1.22474551e+00, -6.33776309e-01,  1.58197942e-01, -4.93211045e-02,
  2.31016997e-02, -1.05271921e-02,  4.29952374e-03, -1.61856521e-03,
  8.41364444e-04, -1.34624594e-04, 2.84210976e-04, -2.01252921e-05])
theory = np.loadtxt("data-theory_grad_des_12params.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_grad_des_12params.txt")[0]
cell = np.loadtxt("c_ell_grad_des_12params.txt")
report.combine(c,theory,pm,cell,"(grad_des_12params, like : -48.76)")

c = np.array([0.63983084, -0.29950152,  0.07198865, -0.04516054])
theory = np.loadtxt("data-theory_grad_des_new.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_grad_des_new.txt")[0]
cell = np.loadtxt("c_ell_grad_des_new.txt")
report.combine(c,theory,pm,cell,"(grad_des, like : -49.82680775609994)")

c = np.array([0.8196409397922872,-0.6642815121383635,0.5504582434204637,-0.3052315604436191])
theory = np.loadtxt("data-theory_best_like_3.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_best_like_3.txt")[0]
cell = np.loadtxt("c_ell_best_like_3.txt")
report.combine(c,theory,pm,cell,"(best like : -47.25)")

c = np.array([-1.2667247001202508,	0.8507695147857159,	-0.5913284827490566,	0.3539920080841348])
theory = np.loadtxt("data-theory_good_like_3.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_good_like_3.txt")[0]
cell = np.loadtxt("c_ell_good_like_3.txt")
report.combine(c,theory,pm,cell,"(good like : -47.28)")

c = np.array([1.1057156324386597,	-0.17641925811767578,	-0.5018882751464844,	0.06964702606201167])
theory = np.loadtxt("data-theory_worst_like_3.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_worst_like_3.txt")[0] 
cell = np.loadtxt("c_ell_worst_like_3.txt")
report.combine(c,theory,pm,cell,"(worst like : -933679.3034482512)")
# Out:
# difference from chain (grad_des_12params, like : -48.76) : 9.615441607144715e-09
# difference from lcdm 60 (grad_des_12params, like : -48.76) : 9.564538007841404e-09
# difference from chain (grad_des, like : -49.82680775609994) : 1.256547078662853e-08
# difference from lcdm 60 (grad_des, like : -49.82680775609994) : 9.564538007841404e-09
# difference from chain (best like : -47.25) : 1.0048102796051374e-08
# difference from lcdm 60 (best like : -47.25) : 9.564538007841404e-09
# difference from chain (good like : -47.28) : 9.681306737319929e-09
# difference from lcdm 60 (good like : -47.28) : 9.564538007841404e-09
# difference from chain (worst like : -933679.3034482512) : 2.58318835638671e-06
# difference from lcdm 60 (worst like : -933679.3034482512) : 9.564538007841404e-09

# %%
c = np.array([-1.2470911145210266, 0.2462870478630066,	-0.3561609983444214,	0.6903726577758789])
theory = np.loadtxt("data-theory_like_60.txt",skiprows=1)[:,1]
pm = np.loadtxt("pm_like_60.txt")[0]
cell = np.loadtxt("c_ell_like_60.txt")
report.combine(c,theory,pm,cell,"(like : -64.22769298710206)")
# Out:
# difference from chain (like : -64.22769298710206) : 1.5197592679333755e-08
# difference from lcdm 60 (like : -64.22769298710206) : 9.564538007841404e-09
