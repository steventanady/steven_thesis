# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
from scipy.optimize import curve_fit
import camb
from camb import model, initialpower

# %%
data = np.loadtxt("output_multinest10.txt", skiprows=272)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(omch2)
# plt.ylim(0,2200)
# plt.ylim(-100,-80)
plt.ylabel("omh2")
plt.title("me linear + camb")
# Out:
# Text(0.5, 1.0, 'me linear + camb')

# %%
data = np.loadtxt("output_multinest9.txt", skiprows=271)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(omch2)
# plt.ylim(0,2200)
# plt.ylim(-100,-80)
plt.ylabel("omh2")
plt.title("kids linear + my comoving")
# Out:
# Text(0.5, 1.0, 'kids linear + my comoving')

# %%
data = np.loadtxt("output_multinest(kids_fixed_LA).txt", skiprows=229)
omch2 = data[:,0]
ombh2 = data[:,1]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(omch2)
# plt.ylim(-100,-80)
plt.ylabel("omh2")
plt.title("kids linear (fixed linear alignment)")
# Out:
# Text(0.5, 1.0, 'kids linear (fixed linear alignment)')

# %%
data = np.loadtxt("output_multinest8.txt", skiprows=235)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2

plt.plot(omh2)
plt.ylabel("omh2")
plt.title("me linear (run4, more iterations)")
# Out:
# Text(0.5, 1.0, 'me linear (run4, more iterations)')

# %%
data = np.loadtxt("output_multinest7.txt", skiprows=235)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2

plt.plot(omh2)
plt.ylabel("omh2")
plt.title("me linear (run3)")
# Out:
# Text(0.5, 1.0, 'me linear (run3)')

# %%
data = np.loadtxt("output_multinest_kids.txt", skiprows=229)
omch2 = data[:,0]
ombh2 = data[:,1]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(post)
plt.ylim(-100,-80)
plt.ylabel("omh2")
plt.title("kids linear")
# Out:
# Text(0.5, 1.0, 'kids linear')

# %%
data = np.loadtxt("output_multinest62.txt", skiprows=235)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2

plt.plot(omh2)
plt.ylabel("omh2")
plt.title("me linear(run 2)")
# Out:
# Text(0.5, 1.0, 'me linear(run 2)')

# %%
data = np.loadtxt("output_multinest6.txt", skiprows=235)
omch2 = data[:,1]
ombh2 = data[:,2]
omh2 = omch2+ombh2

plt.plot(omh2)
plt.ylabel("omh2")
plt.title("me linear")
# Out:
# Text(0.5, 1.0, 'me linear')

# %%
data = np.loadtxt("output_multinest_true.txt", skiprows=229)
omch2 = data[:,0]
ombh2 = data[:,1]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(post)
plt.ylim(-100,-30)
plt.ylabel("omh2")
plt.title("kids non linear")
# Out:
# Text(0.5, 1.0, 'kids non linear')

# %%
data = np.loadtxt("output_multinest_theta60.txt", skiprows=232)
omch2 = data[:,0]
ombh2 = data[:,1]
h0 = data[:,2]
omh2 = omch2+ombh2
post = data[:,-2]

plt.plot(h0)
plt.ylabel("omh2")
plt.title("kids non linear theta60")
# Out:
# Text(0.5, 1.0, 'kids non linear theta60')
