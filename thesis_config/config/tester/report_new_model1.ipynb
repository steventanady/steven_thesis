# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("/home/steven/thesis/mod")
from model_independent import model_independent
from model_independent import Growth_Factor
from model_independent import Report

a = np.loadtxt("a_bg.txt")
k = np.loadtxt("k_hme.txt")
h0=0.6898
om=0.29044350092105475
n=-1
report = Report(om,h0,n)
z = (1-a)/a
z = z[::-1]

# %%
chi_lcdm = np.loadtxt("chi_lcdm.txt")

c = np.array([7.48220115e-01, -1.60535612e-01, -2.03193800e-02,  9.57071570e-03,
  4.80687162e-04, -8.21497385e-04,  6.72126340e-05, 4.43010222e-05,
 -1.75195371e-05, -1.25416101e-05, -8.79040078e-06, -3.93281791e-06])
theory = np.loadtxt("report_new_model/data-theory_grad_des12.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des12.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des12.txt")
report.combine(c,theory,pm,cell,"(grad_des_12params, like : -48.754)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([0.58959676, -0.11762213, -0.0229351])
theory = np.loadtxt("report_new_model/data-theory_grad_des3.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des3.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des3.txt")
report.combine(c,theory,pm,cell,"(grad_des_3params, like : -48.866)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([1.0424880836426196,0.23211911966078302,-0.5041489280873969])
theory = np.loadtxt("report_new_model/data-theory_best_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_best_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_best_like.txt")
report.combine(c,theory,pm,cell,"(best_like, like : -47.57702972169135)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([1.4845788971418674,	0.2631778537828362,	-0.6563990438223881])
theory = np.loadtxt("report_new_model/data-theory_good_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_good_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_good_like.txt")
report.combine(c,theory,pm,cell,"(good_like, like : -47.598230408509586)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([1.2059201002120972,	-0.11947810649871826,	-0.443814754486084])
theory = np.loadtxt("report_new_model/data-theory_worst_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_worst_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_worst_like.txt")
report.combine(c,theory,pm,cell,"(worst_like, like : -337362.26972678496)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()
# Out:
# difference from chain (grad_des_12params, like : -48.754) : 9.619798231640096e-09
# difference from lcdm 60 (grad_des_12params, like : -48.754) : 9.564538007841404e-09
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#      10 plt.show()
#      11 plt.plot(z,chi_lcdm,label = "lcdm")
# ---> 12 plt.plot(z,report.comoving_distance(c,a),label="model")
#      13 plt.legend()
#      15 c = np.array([0.58959676, -0.11762213, -0.0229351])
#
# AttributeError: 'Report' object has no attribute 'comoving_distance'

# %%
report = Report()

c = np.array([7.48220115e-01, -1.60535612e-01, -2.03193800e-02,  9.57071570e-03,
  4.80687162e-04, -8.21497385e-04,  6.72126340e-05, 4.43010222e-05,
 -1.75195371e-05, -1.25416101e-05, -8.79040078e-06, -3.93281791e-06])
theory = np.loadtxt("report_new_model/data-theory_grad_des12.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des12.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des12.txt")
report.combine(c,theory,pm,cell,"(grad_des_12params, like : -48.754)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([0.72196921, -0.15288923, -0.02065917,  0.00706415])
theory = np.loadtxt("report_new_model/data-theory_grad_des4.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des4.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des4.txt")
report.combine(c,theory,pm,cell,"(grad_des_4params, like : -48.734)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([-1.4665944856188557,0.08477871541112725,-0.21832338086260628,0.55687597024763])
theory = np.loadtxt("report_new_model/data-theory_best_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_best_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_best_like.txt")
report.combine(c,theory,pm,cell,"(best_like, like : -47.40528204030314)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([1.4775269944290215,	0.13850194204823763,	0.10008822498158398,	-0.6089932249546527])
theory = np.loadtxt("report_new_model/data-theory_good_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_good_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_good_like.txt")
report.combine(c,theory,pm,cell,"(good_like, like : -47.41264521516746)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()

c = np.array([1.4238442182540894,	-0.5235727429389954,	0.2466830015182495,	-0.4478337287902832])
theory = np.loadtxt("report_new_model/data-theory_worst_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_worst_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_worst_like.txt")
report.combine(c,theory,pm,cell,"(worst_like, like : -682907.2266645718)")
plt.show()
plt.plot(z,chi_lcdm,label = "lcdm")
plt.plot(z,report.comoving_distance(c,a),label="model")
plt.legend()
# Out:
# difference from chain (grad_des_12params, like : -48.754) : 9.619798231640096e-09
# difference from lcdm 60 (grad_des_12params, like : -48.754) : 9.564538007841404e-09
# difference from chain (grad_des_4params, like : -48.734) : 9.755974499080192e-09
# difference from lcdm 60 (grad_des_4params, like : -48.734) : 9.564538007841404e-09
# difference from chain (best_like, like : -47.40528204030314) : 9.618192087711245e-09
# difference from lcdm 60 (best_like, like : -47.40528204030314) : 9.564538007841404e-09
# difference from chain (good_like, like : -47.41264521516746) : 9.620757129504073e-09
# difference from lcdm 60 (good_like, like : -47.41264521516746) : 9.564538007841404e-09
# difference from chain (worst_like, like : -682907.2266645718) : 1.665790830015363e-06
# difference from lcdm 60 (worst_like, like : -682907.2266645718) : 9.564538007841404e-09

# %%
chibest = np.loadtxt("chi_best_like.txt")
chi60 = np.loadtxt("chi_like_60.txt")
chilcdm = np.loadtxt("chi_lcdm.txt")
chiworst = np.loadtxt("chi_worstlike.txt")

print(np.any(np.diff(chibest<0)))
print(np.any(np.diff(chilcdm<0)))
print(np.any(np.diff(chi60<0)))
print(np.any(np.diff(chiworst<0)))
plt.plot(zd,chilcdm,label='lcdm')
plt.plot(zd,chibest,label="best")
plt.plot(zd,chi60,label="60")
plt.plot(zd,chiworst,label="worst")
plt.legend()

# %%
c = np.array([1.3169490818825542,	-0.6674639543734385,	0.7857364522935735	,-0.5873007438564246])
z = np.linspace(0,2,100)
model = model_independent(c,a,h0,om,n)
plt.plot(a,model.lcdm_expf())
plt.plot(a,model.model_expf())
plt.xlim(0.33,1)
# Out:
# (0.33, 1.0)

# %%
report = Report(om,h0,n)

c = np.array([7.48220115e-01, -1.60535612e-01, -2.03193800e-02,  9.57071570e-03,
  4.80687162e-04, -8.21497385e-04,  6.72126340e-05, 4.43010222e-05,
 -1.75195371e-05, -1.25416101e-05, -8.79040078e-06, -3.93281791e-06])
theory = np.loadtxt("report_new_model/data-theory_grad_des12.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des12.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des12.txt")
report.combine(c,theory,pm,cell,"(grad_des_12params, like : -48.754)")
plt.legend()

c = np.array([0.72196921, -0.15288923, -0.02065917,  0.00706415])
theory = np.loadtxt("report_new_model/data-theory_grad_des4.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_grad_des4.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_grad_des4.txt")
report.combine(c,theory,pm,cell,"(grad_des_4params, like : -48.734)")
plt.legend()

c = np.array([-1.4665944856188557,0.08477871541112725,-0.21832338086260628,0.55687597024763])
theory = np.loadtxt("report_new_model/data-theory_best_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_best_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_best_like.txt")
report.combine(c,theory,pm,cell,"(best_like, like : -47.40528204030314)")
plt.legend()

c = np.array([1.4775269944290215,	0.13850194204823763,	0.10008822498158398,	-0.6089932249546527])
theory = np.loadtxt("report_new_model/data-theory_good_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_good_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_good_like.txt")
report.combine(c,theory,pm,cell,"(good_like, like : -47.41264521516746)")
plt.legend()

c = np.array([1.4238442182540894,	-0.5235727429389954,	0.2466830015182495,	-0.4478337287902832])
theory = np.loadtxt("report_new_model/data-theory_worst_like.txt",skiprows=1)[:,1]
pm = np.loadtxt("report_new_model/pm_worst_like.txt")[0]
cell = np.loadtxt("report_new_model/c_ell_worst_like.txt")
report.combine(c,theory,pm,cell,"(worst_like, like : -682907.2266645718)")
plt.legend()
# Out:
# difference from chain (grad_des_12params, like : -48.754) : 9.619798231640096e-09
# difference from lcdm 60 (grad_des_12params, like : -48.754) : 9.564538007841404e-09
# difference from chain (grad_des_4params, like : -48.734) : 9.755974499080192e-09
# difference from lcdm 60 (grad_des_4params, like : -48.734) : 9.564538007841404e-09
# difference from chain (best_like, like : -47.40528204030314) : 9.618192087711245e-09
# difference from lcdm 60 (best_like, like : -47.40528204030314) : 9.564538007841404e-09
# difference from chain (good_like, like : -47.41264521516746) : 9.620757129504073e-09
# difference from lcdm 60 (good_like, like : -47.41264521516746) : 9.564538007841404e-09
# difference from chain (worst_like, like : -682907.2266645718) : 1.665790830015363e-06
# difference from lcdm 60 (worst_like, like : -682907.2266645718) : 9.564538007841404e-09
